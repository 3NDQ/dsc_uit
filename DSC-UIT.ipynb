# %%
import os
import torch
import json
import sys
from pprint import pprint
from PIL import Image
import matplotlib.pyplot as plt

# %% [markdown]
# # WARMUP PHASE

# %%
json_path = './Warmup Phase/vimmsd-warmup.json'
image_path = './Warmup Phase/warmup-images/'

# %%
with open(json_path, 'r', encoding='utf8') as f:
    data = json.load(f)
pprint(data)
# Out:
# {'100': {'caption': 'Zalo tiện thật, kết nối được cả âm dương',
#          'image': 'd2e1057c0539037774066ba31e21af90a4e11a237da24ae3f52366896df01c14.jpg',
#          'label': 'multi-sarcasm'},
#  '10050': {'caption': 'Mời được idol này nữa thì phải nói là đỉnh',
#            'image': '0dd998834fe3842f8c7189b72ab1fe9a6c07969922181c2a4bfdd8256a889af4.jpg',
#            'label': 'multi-sarcasm'},
#  '10220': {'caption': 'Ai rồi cũng khác',
#            'image': 'f2dc64b8c3ac4fda94d59a90fcdbe20dd59a6c5d77bf3023f5c5f3fe6b003353.jpg',
#            'label': 'not-sarcasm'},
#  '103': {'caption': 'Không biết shipper với khách ai quá đáng hơn luôn á 😅',
#          'image': 'b8255048090ce4027f1ddfd3bac66e417aaf30c598cd5a113891340422920480.jpg',
#          'label': 'multi-sarcasm'},
#  '10334': {'caption': 'Kim Soo Hyun đã xuất hiện tại Baeksang 2024 ❤️',
#            'image': '547be8e138616ddc9324f870c3889310c3779b1bb576224b0919149299402c89.jpg',
#            'label': 'not-sarcasm'},
# ...

# %%
data.keys()
# Out:
# dict_keys(['464', '7413', '3808', '5816', '1632', '3674', '9636', '7135', '2991', '7609', '6456', '6046', '4345', '3514', '8864', '192', '5079', '1275', '244', '10619', '3366', '5591', '2923', '6857', '8795', '10220', '4360', '10794', '10803', '8658', '2405', '9066', '5045', '9369', '4712', '10679', '10334', '9618', '5704', '812', '2938', '10746', '968', '6898', '1533', '5577', '100', '8551', '1160', '7332', '844', '9763', '10050', '5373', '9684', '5584', '3591', '6197', '10345', '4522', '7320', '4122', '7336', '8896', '5414', '8440', '2003', '6163', '1919', '495', '1580', '9097', '4677', '6956', '6778', '6856', '7685', '9231', '4553', '1324', '4604', '7791', '6210', '6391', '8507', '4969', '3032', '103', '6559', '3422', '250', '7519', '10403', '6249', '17', '2579', '7643', '4760', '6601', '961', '4802'])

# %%
def visualize(data : dict, idx : int) -> None:
    temp = set()
    for i in data.keys()
        temp.add(i)
    print(temp)
print(data['100']['caption'])
image = Image.open(image_path + data['100']['image'])
plt.axis('off')
plt.imshow(image)
# Out:
# Zalo tiện thật, kết nối được cả âm dương
